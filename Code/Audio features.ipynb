# %% [markdown]
# #### Create a function that input a song and return audio features

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
import pandas as pd

# %% [markdown]
# #### Connecting to API

# %%
sp = spotipy.Spotify(client_credentials_manager=SpotifyClientCredentials(client_id='336f28498ae24f02b7a02f5b5d8e9754',
                                                                              client_secret='a0934a41880a46b9a343c1d49529b1bc'))

# %%
def analyze_playlist(creator, playlist_id):
    
    # Create empty dataframe
    playlist_features_list = ["artist", "album", "track_name", "track_id", 
                             "danceability", "energy", "key", "loudness", "mode", "speechiness",
                             "instrumentalness", "liveness", "valence", "tempo", "duration_ms", "time_signature"]
    playlist_df = pd.DataFrame(columns = playlist_features_list)
    
    # Create empty dict
    playlist_features = {}
    
    # Loop through every track in the playlist, extract features and append the features to the playlist df
    playlist = sp.user_playlist_tracks(creator, playlist_id)["items"]
    for track in playlist:
        # Get metadata
        playlist_features["artist"] = track["track"]["album"]["artists"][0]["name"]
        playlist_features["album"] = track["track"]["album"]["name"]
        playlist_features["track_name"] = track["track"]["name"]
        playlist_features["track_id"] = track["track"]["id"]
        # Get audio features
        audio_features = sp.audio_features(playlist_features["track_id"])[0]
        for feature in playlist_features_list[4:]:
            playlist_features[feature] = audio_features[feature]
        
        # Concat the dfs
        track_df = pd.DataFrame(playlist_features, index = [0])
        playlist_df = pd.concat([playlist_df, track_df], ignore_index = True)
        
    return playlist_df

# %%
playlist_creator = 'Spotify'
playlist_id = 'spotify:playlist:37i9dQZF1DX50QitC6Oqtn'

# %%
love_pop = analyze_playlist(playlist_creator,playlist_id)

# %%
love_pop
# Out:
#             artist                   album                       track_name  \
# 0             RAYE       Love Of Your Life                Love Of Your Life
# 1    Ariana Grande               Positions                              pov
# 2     Dan Talevski        Don't Ever Leave                 Don't Ever Leave
# 3             LANY              mama's boy                      nobody else
# 4       Aloe Blacc     All Love Everything              All Love Everything
# ..             ...                     ...                              ...
# 95            Lauv         i'm so tired...                  i'm so tired...
# 96            Dido             Give You Up                      Give You Up
# 97          RITUAL            Love Me Back                     Love Me Back
# 98  Julia Michaels  Inner Monologue Part 1  What A Time (feat. Niall Horan)
# 99      Dean Lewis               7 Minutes                        7 Minutes
#
# ...

# %%
playlist_creator = 'Spotify'
playlist_id = 'spotify:playlist:37i9dQZF1DXdPec7aLTmlC'

# %%
mood = analyze_playlist(playlist_creator,playlist_id)

# %%
mood
# Out:
#             artist                                              album  \
# 0         Swae Lee  Krabby Step (with Tyga & Lil Mosey) [Music Fro...
# 1         24kGoldn  Mood (Remix) feat. Justin Bieber, J Balvin & i...
# 2        Engelwood                                           Crust Fm
# 3            Nelly                                            Lil Bit
# 4      Ritt Momney                                Put Your Records On
# ..             ...                                                ...
# 95     Tom Grennan                                  This is the Place
# 96  Jonas Brothers                                What A Man Gotta Do
# 97       Sam Feldt                          2 Hearts (feat. Gia Koka)
# 98    Julie Bergan                                      Kiss Somebody
# 99       Hot Shade                                               Dive
#
#                                            track_name                track_id  \
# ...

# %%
playlist_creator = 'Spotify'
playlist_id = 'spotify:playlist:37i9dQZF1DWV1PBrIG2weG'

# %%
chill = analyze_playlist(playlist_creator,playlist_id)

# %%
chill
# Out:
#                    artist                                  album  \
# 0                Dua Lipa                                  Fever
# 1           Ariana Grande                              Positions
# 2               Sam Smith                              Love Goes
# 3   Oneohtrix Point Never                           Midday Suite
# 4                  Alizzz                           El Encuentro
# ..                    ...                                    ...
# 95                Caribou                               Suddenly
# 96                     LP  Girls Go Wild (feat. Ximena Sariñana)
# 97          Jeremy Zucker                      love is not dying
# 98            Alina Baraz                              Endlessly
# 99           Fred again..                     Kyle (I Found You)
#
#                                track_name                track_id  \
# 0                                   Fever  3wJVBz7gvGTwTWVAxFa6ny
# ...

# %%
playlist_creator = 'Spotify'
playlist_id = 'spotify:playlist:37i9dQZF1DX0BcQWzuB7ZO'

# %%
dance = analyze_playlist(playlist_creator,playlist_id)

# %%
dance
# Out:
#         artist                                              album  \
# 0   Joel Corry                          Head & Heart (feat. MNEK)
# 1       Tiësto                                       The Business
# 2          KSI  Really Love (feat. Craig David & Digital Farm ...
# 3    SAINt JHN                              Roses (Imanbek Remix)
# 4        Topic                                        Breaking Me
# ..         ...                                                ...
# 65     Kaskade                   Chains Chilled (with Project 46)
# 66     BRONSON                                            BRONSON
# 67          MK                                                2AM
# 68  Disclosure                                    ENERGY (Deluxe)
# 69    SG Lewis                                          Chemicals
#
#                                            track_name                track_id  \
# 0                           Head & Heart (feat. MNEK)  6cx06DFPPHchuUAcTxznu9
# ...

# %%
playlist_creator = 'Spotify'
playlist_id = 'spotify:playlist:79644V4s1FuyyM38pgI07B'

# %%
tecno = analyze_playlist(playlist_creator,playlist_id)

# %%
tecno
# Out:
#                artist                                              album  \
# 0               Diplo                                         On My Mind
# 1              MEDUZA                  Piece Of Your Heart (The Remixes)
# 2              Tchami                  Rainforest (Valentino Khan Remix)
# 3   Armand Van Helden  Give Me Your Loving (feat. Lorne) [Martin Ikin...
# 4         Kyle Watson                                          I Got You
# 5      Guantanamo Bae                                       Midnight Run
# 6              FISHER                                             Freaks
# 7        One True God                                               Hush
# 8             Matroda                                  Jack The House EP
# 9               Steny                                       Modular Bits
# 10             Tiësto                 God Is A Dancer (James Hype Remix)
# 11            Atushka                                   Feeling the Rain
# ...

# %%
playlist_creator = 'Spotify'
playlist_id = 'spotify:playlist:5fWeZI5FLdUkowl4qaglPi'

# %%
HipHop = analyze_playlist(playlist_creator,playlist_id)

# %%
HipHop
# Out:
#              artist                                          album  \
# 0          Ice Cube                                 The Essentials
# 1   Digable Planets  Reachin' (A New Refutation Of Time And Space)
# 2              2Pac          2Pac Greatest Hits (Explicit Version)
# 3             Luniz                             Operation Stackola
# 4    Bell Biv DeVoe                                         Poison
# ..              ...                                            ...
# 57   Heltah Skeltah                                      Nocturnal
# 58            Rakim             The 18th Letter / The Book Of Life
# 59              DMX                        ...And Then There Was X
# 60             2Pac          2Pac Greatest Hits (Explicit Version)
# 61             2Pac                                  Greatest Hits
#
#                             track_name                track_id  danceability  \
# 0                    It Was A Good Day  2MuJbBWAVewREJmB8WdGJ3         0.780
# ...

# %%
playlist_creator = 'Spotify'
playlist_id = 'spotify:playlist:37i9dQZF1DXbTxeAdrVG2l'

# %%
all90s = analyze_playlist(playlist_creator,playlist_id)

# %%
all90s
# Out:
#                artist                                              album  \
# 0     Backstreet Boys                              The Hits--Chapter One
# 1   Natalie Imbruglia                        Glorious: The Singles 97-07
# 2             East 17                                              Steam
# 3             Roxette                             It Must Have Been Love
# 4               Oasis                                    Stop The Clocks
# ..                ...                                                ...
# 95    Eros Ramazzotti                                       Tutte storie
# 96       Shania Twain                                       Come On Over
# 97      Guns N' Roses                                Use Your Illusion I
# 98     George Michael  Ladies And Gentlemen... The Best Of George Mic...
# 99               Dido                                           No Angel
#
#                                            track_name                track_id  \
# ...

# %%
playlist_creator = 'Spotify'
playlist_id = 'spotify:playlist:6RXgHyqUiEbSmX7NQZ05yQ'

# %%
tiktok = analyze_playlist(playlist_creator,playlist_id)

# %%
tiktok
# Out:
#             artist                            album  \
# 0          Cardi B  WAP (feat. Megan Thee Stallion)
# 1         24kGoldn           Mood (feat. iann dior)
# 2      Mario Judah                   Die Very Rough
# 3        Sada Baby              Whole Lotta Choppas
# 4     Championxiii                             BOO!
# ..             ...                              ...
# 95  Arizona Zervas                          ROXANNE
# 96     Ritt Momney              Put Your Records On
# 97     Sally Sossa                        100 Flows
# 98        Saweetie                           Tap In
# 99         Bagluck                        Ether Way
#
#                          track_name                track_id  danceability  \
# 0   WAP (feat. Megan Thee Stallion)  4Oun2ylbjFKMPTiaSbbCih         0.935
# 1            Mood (feat. iann dior)  3tjFYV6RSFtuktYl3ZtYcq         0.700
# 2                    Die Very Rough  1AyrLa7PkFQvt1A6XQY3ff         0.720
# ...

# %%
playlist_creator = 'Spotify'
playlist_id = 'spotify:playlist:1onndIHH5pZLn0fleGgLjD'

# %%
trending = analyze_playlist(playlist_creator,playlist_id)

# %%
trending
# Out:
#             artist                                    album  \
# 0     Travis Scott                               ASTROWORLD
# 1    Lewis Capaldi  Divinely Uninspired To A Hellish Extent
# 2              NDJ                       Catch A Body (123)
# 3       The Weeknd                              After Hours
# 4        John Wolf                                     FAIR
# ..             ...                                      ...
# 58    Harry Styles                                Fine Line
# 59           Topic                              Breaking Me
# 60     Roddy Ricch    Please Excuse Me For Being Antisocial
# 61  StaySolidRocky                               Party Girl
# 62          DaBaby                         BLAME IT ON BABY
#
#                       track_name                track_id  danceability  \
# 0                     SICKO MODE  2xLMifQCjDGFmkHkpNLD9h         0.834
# 1              Someone You Loved  7qEHsqek33rTcFNT9PFqLf         0.501
# ...

# %%
playlist_creator = 'Spotify'
playlist_id = 'spotify:playlist:37i9dQZF1DX9gKTxAbfFfX'

# %%
verano = analyze_playlist(playlist_creator,playlist_id)

# %%
verano
# Out:
#                artist                                              album  \
# 0          Rafa Pabön                                            A Güiro
# 1             Ptazeta                                               Mami
# 2    Lost Frequencies                                       Cup Of Beats
# 3            J Balvin                     UN DIA (ONE DAY) (Feat. Tainy)
# 4       Zion & Lennox                                          Te Mueves
# 5            Ana Mena                               A Un Paso De La Luna
# 6            88rising  Midsummer Madness 20 (feat. Joji, Rich Brian, ...
# 7   Funzo & Baby Loud                                              PECA2
# 8           SAINt JHN                Roses (Imanbek Remix [Latino Gang])
# 9         La Pegatina                                    Darle la vuelta
# 10               Rvfv                                             Trendy
# 11               Kygo                      What's Love Got to Do with It
# ...

# %%
playlist_creator = 'Spotify'
playlist_id = 'spotify:playlist:2f6tXtN0XesjONxicAzMIw'

# %%
all2000 = analyze_playlist(playlist_creator,playlist_id)

# %%
all2000
# Out:
#                artist                                     album  \
# 0               Usher            Confessions (Expanded Edition)
# 1              T-Pain                                  Epiphany
# 2       Metro Station                             Metro Station
# 3             Shakira  Oral Fixation, Vol. 2 (Expanded Edition)
# 4   Justin Timberlake                      Mirrors (Radio Edit)
# ..                ...                                       ...
# 95   Bowling For Soup              A Hangover You Don't Deserve
# 96      Avril Lavigne                             Under My Skin
# 97      Jordin Sparks                             Jordin Sparks
# 98        Chris Brown                                   Forever
# 99            Beyoncé                       I AM...SASHA FIERCE
#
#                             track_name                track_id  danceability  \
# 0     Yeah! (feat. Lil Jon & Ludacris)  5rb9QrpfcKFHM1EUbSIurX         0.894
# ...

# %%
playlist_creator = 'Spotify'
playlist_id = 'spotify:playlist:6IfGK9nLC9ChgD7FTZzkLJ'

# %%
partyhits = analyze_playlist(playlist_creator,playlist_id)

# %%
partyhits
# Out:
#                      artist                  album  \
# 0                 SAINt JHN  Roses (Imanbek Remix)
# 1                    Tiësto                 Ritual
# 2             Justin Bieber       Purpose (Deluxe)
# 3                     Kesha              High Road
# 4   Macklemore & Ryan Lewis              The Heist
# ..                      ...                    ...
# 95      5 Seconds of Summer             Youngblood
# 96          Natalie La Rose               Somebody
# 97                 Jessie J              Price Tag
# 98             David Guetta                      7
# 99             Daddy Yankee                   Dura
#
#                                      track_name                track_id  \
# 0                         Roses - Imanbek Remix  24Yi9hE78yPEbZ4kxyoXAI
# 1                                        Ritual  3M9Apu4OZfylLTFKvgEtKa
# 2                                         Sorry  69bp2EbF7Q2rqc5N3ylezZ
# ...

# %%
playlist_creator = 'Spotify'
playlist_id = 'spotify:playlist:6vDGVr652ztNWKZuHvsFvx'

# %%
house = analyze_playlist(playlist_creator,playlist_id)

# %%
house
# Out:
#                   artist                      album  \
# 0               Harrison               Lucid Dreams
# 1            Felix Jaehn                 No Therapy
# 2             Joel Corry  Head & Heart (feat. MNEK)
# 3                 MEDUZA               Lose Control
# 4                 Regard                    Secrets
# ..                   ...                        ...
# 75                 YANIC                     Remedy
# 76  Braaten & Chrit Leaf             Scream My Name
# 77                  AZ2A          Genie in a Bottle
# 78        Tobias Bergson                 Can't Wait
# 79           T. Matthias         Would I Lie to You
#
#                    track_name                track_id  danceability  energy  \
# 0                Lucid Dreams  60BTRjzBJpDUpmlC7NgtBw         0.752   0.781
# 1                  No Therapy  7tUTCcqkMCnC9qLqbQeI0T         0.773   0.608
# 2   Head & Heart (feat. MNEK)  6cx06DFPPHchuUAcTxznu9         0.734   0.874
# ...

# %%
playlist_creator = 'Topsify Spain'
playlist_id = 'spotify:playlist:5jtCTvfTMl87Dwfm9rpX6d'

# %%
spanish_pop = analyze_playlist(playlist_creator,playlist_id)

# %%
spanish_pop
# Out:
#             artist                          album  \
# 0    Pablo Alborán            Si hubieras querido
# 1           Alizzz                   El Encuentro
# 2      Nil Moliner                          Calma
# 3    Justin Quiles                          Jeans
# 4   Álvaro De Luna        Juramento eterno de sal
# ..             ...                            ...
# 95   Vanesa Martín                    Caída libre
# 96     Nil Moliner            Soldadito de Hierro
# 97   Pablo Alborán                Peces de Ciudad
# 98       Sinsinati              Indios y Vaqueros
# 99    Don Patricio  La Dura Vida del Joven Rapero
#
#                               track_name                track_id  \
# 0                    Si hubieras querido  0Q6Pc3dqsl6qHKZ91DPUTH
# 1                           El Encuentro  0PbDj1Lh8uZJ2ZcTRSBvQf
# 2                                  Calma  1KDNgzP7ly6ge8j0vnrfpD
# 3                                  Jeans  3GtnId3Cm1Xa6joCj08nzW
# ...

# %%
playlist_creator = 'crisvascez'
playlist_id = 'spotify:playlist:3nHylKOqdjGHrgUewxIYPQ'

# %%
indie = analyze_playlist(playlist_creator,playlist_id)

# %%
indie
# Out:
#                artist                       album  \
# 0             Wallows             Nothing Happens
# 1              Clairo                 Pretty Girl
# 2              kindly                Slow Dancing
# 3             Lil Eli                     Walter!
# 4           Revelries             Blinding Lights
# ..                ...                         ...
# 95  Cage The Elephant                  Melophobia
# 96       The Growlers                   City Club
# 97           TEMPOREX                        Care
# 98          Grouplove    Never Trust a Happy Song
# 99        The Frights  You Are Going to Hate This
#
#                            track_name                track_id  danceability  \
# 0   Are You Bored Yet? (feat. Clairo)  57RA3JGafJm5zRtKJiKPIm         0.682
# 1                         Pretty Girl  0KyAGiNGUytG5JLxJu4F6l         0.930
# 2                        Slow Dancing  1IyNCqVA1VkIYoemTjjRfI         0.606
# ...

# %%
playlist_creator = 'Topsify Spain'
playlist_id = 'spotify:playlist:7cpsiaUizVTdQFm0nsF8RL'

# %%
exits = analyze_playlist(playlist_creator,playlist_id)

# %%
exits
# Out:
#                artist                                        album  \
# 0       Fleetwood Mac                       Rumours (Super Deluxe)
# 1   Alanis Morissette           Jagged Little Pill (2015 Remaster)
# 2          Ed Sheeran                           x (Deluxe Edition)
# 3   Portugal. The Man      Tomorrow (from “At home with the kids”)
# 4           Tom Petty  Wildflowers & All The Rest (Deluxe Edition)
# ..                ...                                          ...
# 95     The Black Keys                                    El Camino
# 96      Pablo Alborán                      Tanto (Edición Premium)
# 97          Veintiuno                                      Gourmet
# 98      Ivan Ferreiro                                         Casa
# 99  Alanis Morissette           Jagged Little Pill (2015 Remaster)
#
#                                 track_name                track_id  \
# 0                   Dreams - 2004 Remaster  0ofHAoxe9vBkTCp2UQIavz
# ...

# %%
playlist_creator = 'grings-br'
playlist_id = 'spotify:playlist:5exEuw03PxcVAOwP87iZDl'

# %%
pop_rock_80_90 = analyze_playlist(playlist_creator,playlist_id)

# %%
pop_rock_80_90
# Out:
#                               artist  \
# 0                       Depeche Mode
# 1                      Guns N' Roses
# 2                              Queen
# 3                       Led Zeppelin
# 4                             R.E.M.
# ..                               ...
# 95                           Shanice
# 96  Jeff Zavac featuring The Craetts
# 97                         Green Day
# 98                         Green Day
# 99                   The Cranberries
#
#                                                 album  \
# 0                           Live in Berlin Soundtrack
# 1                            Appetite For Destruction
# 2                A Night At The Opera (2011 Remaster)
# 3                    Led Zeppelin IV (Deluxe Edition)
# 4               In Time: The Best Of R.E.M. 1988-2003
# ..                                                ...
# 95                                        Inner Child
# 96  Miami Lighthouse for the Blind Presents: Instr...
# ...

# %%
playlist_creator = 'alfonso.dcv'
playlist_id = 'spotify:playlist:7u68csid30Z7CkAyVQ4Ka4'

# %%
techhouse = analyze_playlist(playlist_creator,playlist_id)

# %%
techhouse
# Out:
#                artist                           album  \
# 0           Aida Arko  Prolo Therapy (Frühwerk Remix)
# 1     Various Artists            Syndication, Vol. 40
# 2               Morsy                   Get Me Higher
# 3        Alex Luciano                  Under the Rain
# 4                N3UX                     In The Dark
# ..                ...                             ...
# 95         Rone White              Little Helpers 362
# 96     Meli Rodriguez                           Intro
# 97             D'Gian                     Make My Day
# 98             Versus                        Demented
# 99  Yungness & Jaminn                      What To Do
#
#                         track_name                track_id  danceability  \
# 0   Prolo Therapy - Frühwerk Remix  7hCkjBcS4XmJAMjaEQoRlJ         0.693
# 1     Laugh & Relax - Original Mix  3zDVoFx8ve0hEWlPOsTDzF         0.762
# 2                    Get Me Higher  7Bv2XOMpXy9QkBDam3f0TJ         0.690
# ...

# %%
data_list = [love_pop,mood,chill,dance,tecno,HipHop,all90s,tiktok,trending,verano,all2000,partyhits,house,spanish_pop,indie,exits,pop_rock_80_90,techhouse]

# %%
final = pd.concat(data_list)

# %%
final
# Out:
#                artist                album           track_name  \
# 0                RAYE    Love Of Your Life    Love Of Your Life
# 1       Ariana Grande            Positions                  pov
# 2        Dan Talevski     Don't Ever Leave     Don't Ever Leave
# 3                LANY           mama's boy          nobody else
# 4          Aloe Blacc  All Love Everything  All Love Everything
# ..                ...                  ...                  ...
# 95         Rone White   Little Helpers 362  Little Helper 362-4
# 96     Meli Rodriguez                Intro                Intro
# 97             D'Gian          Make My Day          Make My Day
# 98             Versus             Demented             Demented
# 99  Yungness & Jaminn           What To Do           What To Do
#
#                   track_id  danceability  energy key  loudness mode  \
# 0   5iqfKcEGKhoeWTNqmZPiu3         0.632   0.826  10    -5.326    0
# ...

# %%
final.to_csv('..\data\SpotifyDataframe')
